# %%
import pandas as pd
from functools import lru_cache
import ast
import re

import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
import sys
sys.path.append("/Users/tahreemyasir/Documents/prelims/DT_hint-1")

from dt_code.GPT.csv_baseline_1 import convert_rule_to_short_name

# %% [markdown]
# # Loading data into separate df's

# %%
df_1 = pd.read_csv('/Users/tahreemyasir/Documents/prelims/DT_hint-1/Data/csv/gpt-o3/gpt_baseline_1.csv')
df_2 = pd.read_csv('/Users/tahreemyasir/Documents/prelims/DT_hint-1/Data/csv/gpt-o3/gpt_baseline_2.csv')
df_3 = pd.read_csv('/Users/tahreemyasir/Documents/prelims/DT_hint-1/Data/csv/gpt-o3/gpt_ours.csv')

# Convert all 'id' columns to integer to ensure consistent dtype for merging
# Handle different formats: '[450]', '450', or already integer
def convert_id_to_int(id_value):
    if pd.isna(id_value):
        return id_value
    id_str = str(id_value).strip('[]')
    return int(id_str)

df_1['id'] = df_1['id'].apply(convert_id_to_int)
df_2['id'] = df_2['id'].apply(convert_id_to_int)
df_3['id'] = df_3['id'].apply(convert_id_to_int)

# df_1.isnull().sum()   
print("original number of rows baseline 1: ", len(df_1))
print("original number of rows baseline 2: ", len(df_2))
print("original number of rows baseline 3: ", len(df_3))

print("unique ids baseline 1: ", df_1['id'].nunique())
print("unique ids baseline 2: ", df_2['id'].nunique())
print("unique ids baseline 3: ", df_3['id'].nunique())

print("columns baseline 1: ", df_1.shape[1])
print("columns baseline 2: ", df_2.shape[1])
print("columns baseline 3: ", df_3.shape[1])

df = (
    df_1
    .merge(df_2, on="id", how="inner")
    .merge(df_3, on="id", how="inner")
)

print("columns merged: ", df.shape[1])
print("rows merged: ", df.shape[0])
print("unique ids merged: ", df['id'].nunique())
df.isnull().sum()
# Out:
# original number of rows baseline 1:  516
# original number of rows baseline 2:  516
# original number of rows baseline 3:  516
# unique ids baseline 1:  516
# unique ids baseline 2:  516
# unique ids baseline 3:  516
# columns baseline 1:  43
# columns baseline 2:  12
# columns baseline 3:  15
# columns merged:  68
# rows merged:  516
# unique ids merged:  516
# id                                         0
# record_number                              0
# problem_number                             0
# conclusion                                 0
# givens                                     0
# intermediate_expressions                   0
# known_expressions                          0
# length_givens                              0
# length_intermediate_expressions            0
# filtered_derivation_keys                   0
# KG_plan                                    2
# KG_rule                                    2
# KG_complexity                              0
# KG_step                                    2
# KG_distance                                0
# KG_frequency                               2
# KG_depth                                   2
# student_reasoning                          2
# student_candidates                         2
# student_step                               2
# student_rule                               2
# student_complexity                         0
# student_depth                             23
# student_distance                           0
# student_frequency                         95
# student_parent_statements                  0
# student_parent_complexities                0
# student_completion_tokens                  0
# student_completion_time                    0
# teacher_student_errors                     0
# next_step_correctness_x                    0
# teacher_rule                               0
# teacher_parent_statements                  0
# teacher_parent_complexities                0
# teacher_feedback                           0
# teacher_completion_tokens                  0
# teacher_completion_time                    0
# student_update_step                        0
# student_update_rule                        1
# student_update_revised_reasoning           0
# student_update_parent_statements           0
# student_update_completion_tokens           0
# student_update_completion_time             0
# next_step_correctness_y                    0
# judge_feedback                             0
# judge_student_errors                       0
# judge_completion_tokens                    0
# judge_completion_time                      0
# judge_student_update_step                  0
# judge_student_update_rule                  0
# judge_student_update_revised_reasoning     0
# judge_student_update_parent_statements     0
# judge_student_update_completion_tokens     0
# judge_student_update_completion_time       0
# student_errors_ours                        0
# next_step_correctness_ours                 0
# teacher_feedback_correctness_ours          0
# teacher_rule_correctness_ours              0
# judge_action_ours                          0
# final_feedback_ours                        0
# ours_completion_tokens                     0
# ours_completion_time                       0
# ours_student_update_step                   0
# ours_student_update_rule                   0
# ours_student_update_revised_reasoning      0
# ours_student_update_parent_statements      0
# ours_student_update_completion_tokens      0
# ours_student_update_completion_time        0
# dtype: int64

# %% [markdown]
# # preprocessing

# %%
#apply convert_rule_to_short_name(rule_name) to student_rule, student_update_rule, judge_student_update_rule, ours_student_update_rule from gpt/csv_baseline_1.py
from dt_code.GPT.csv_baseline_1 import convert_rule_to_short_name
# remove space from KG_rule, student_rule, student_update_rule, judge_student_update_rule, ours_student_update_rule
df['KG_rule'] = df['KG_rule'].str.replace(' ', '')
df['student_rule'] = df['student_rule'].str.replace(' ', '')
df['student_update_rule'] = df['student_update_rule'].str.replace(' ', '')
df['judge_student_update_rule'] = df['judge_student_update_rule'].str.replace(' ', '')
df['ours_student_update_rule'] = df['ours_student_update_rule'].str.replace(' ', '')

for col in [
    'KG_rule',
    'student_rule', 
    'student_update_rule',
    'judge_student_update_rule',
    'ours_student_update_rule'
]:
    if col in df.columns:
        df[col] = df[col].astype(str).apply(convert_rule_to_short_name)


#Removing spaces from the columns
df['KG_step_new'] = df['KG_step'].str.replace(' ', '')
df['student_step_new'] = df['student_step'].str.replace(' ', '')
df['student_update_step_new'] = df['student_update_step'].str.replace(' ', '')
df['judge_student_update_step_new'] = df['judge_student_update_step'].str.replace(' ', '')
df['ours_student_update_step'] = df['ours_student_update_step'].str.replace(' ', '')
# remove '(' and ')' from the student_step and student_update_plan and KG_step
df['student_step_new'] = df['student_step'].str.replace('(', '').str.replace(')', '')
df['student_update_step_new'] = df['student_update_step'].str.replace('(', '').str.replace(')', '')
df['KG_step_new'] = df['KG_step'].str.replace('(', '').str.replace(')', '')
df['judge_student_update_step_new'] = df['judge_student_update_step'].str.replace('(', '').str.replace(')', '')
df['ours_student_update_step_new'] = df['ours_student_update_step'].str.replace('(', '').str.replace(')', '')



# count rows where student_distance == 0
print("number of rows where student_distance == 0: ", len(df_1[df_1['student_distance'] == 0]))
# show the rows where student_distance == 0
print(df[df['student_distance'] == 0][['conclusion', 'student_step', 'student_distance']])
# add 7 to the student_distance column
df['student_distance'] = df['student_distance'].fillna(0)
# replace 0 with 7 in the student_distance column
df['student_distance'] = df['student_distance'].replace(0, 7)
print(df[df['student_distance'] == 0][['conclusion', 'student_step', 'student_distance']])
# setting the student_depth to 3 if it is None
df['student_depth'] = df['student_depth'].fillna(3)
#if student_depth <0 set it to 3
df['student_depth'] = df['student_depth'].apply(lambda x: 3 if x < 0 else x)
print("student depth unique values: ", df['student_depth'].unique())
df['student_distance'] = df['student_distance'].apply(lambda x: 3 if x < 0 else x)
print("student distance unique values: ", df['student_distance'].unique())

#apply rule name preprocessing to student_rule, student_update_rule, judge_student_update_rule, ours_student_update_rule from gpt/csv_baseline_1.py
from dt_code.GPT.csv_baseline_1 import convert_rule_to_short_name

for col in [
    'KG_rule',
    'student_rule',
    'student_update_rule',
    'judge_student_update_rule',
    'ours_student_update_rule'
]:
    if col in df.columns:
        df[col] = df[col].astype(str).apply(convert_rule_to_short_name)

# Safe function to evaluate literal expressions - handles both strings and already-parsed lists
def safe_literal_eval(x):
    if isinstance(x, str):
        return ast.literal_eval(x)
    elif isinstance(x, (list, tuple)):
        return x
    else:
        return x

df['student_parent_complexities'] = df['student_parent_complexities'].apply(safe_literal_eval)

# Create known_expressions_length and parents_length columns for use in later cells
if 'known_expressions' in df.columns:
    df['known_expressions'] = df['known_expressions'].apply(safe_literal_eval)
    df['known_expressions_length'] = df['known_expressions'].apply(len)
if 'student_parent_statements' in df.columns:
    df['student_parent_statements'] = df['student_parent_statements'].apply(safe_literal_eval)
    df['parents_length'] = df['student_parent_statements'].apply(len)
# Out:
# number of rows where student_distance == 0:  5
#     conclusion student_step  student_distance
# 27       (Q>R)          NaN                 0
# 133          Y        (S>Y)                 0
# 159          Y          NaN                 0
# 162          Y       (-S+Y)                 0
# 398     (M*-Z)      -(-K+R)                 0
# Empty DataFrame
# Columns: [conclusion, student_step, student_distance]
# Index: []
# student depth unique values:  [1. 2. 3. 4. 6. 5. 0.]
# student distance unique values:  [1 2 3 4 7 5 6]

# %% [markdown]
# # Optimal comparison

# %%
#count the number of rows where student_step == KG_step
df['count_student'] = df.apply(lambda row: 1 if (row['student_step_new'] == row['KG_step_new']) & (row['student_rule'] == row['KG_rule']) else 0, axis=1)
print("================================================")
#optimal steps
print("Optimal number of steps: ", df['count_student'].sum())
pre_count = df['count_student'].sum()  # Count of optimal steps
pre = pre_count/df.shape[0]  # Proportion of optimal steps
print("Optimal number of steps: ", pre)
df_opt = df[df['count_student'] == 1].copy()
df_in = df[df['count_student'] == 0].copy()

# optimal step complexity
print("mean complexity of optimal steps: ", df_opt['student_complexity'].mean())
print("mean distance of optimal steps: ", df_opt['student_distance'].mean())
# optimal step already derived statements... 
# optimal step parents complexity 
# print("mean complexity of parent statements for optimal steps: ", 
#       df_opt['student_parent_complexities'].apply(lambda x: sum(x)/len(x) if len(x) > 0 else 10).mean())
# print("optimal steps mean derived statements: ", df_opt['known_expressions_length'].mean())
# print("optimal steps parents complexitys: ", df_opt['student_parent_complexities'].apply(lambda x: sum(x)/len(x) if len(x) > 0 else 10).mean())
# print("optimal steps mean parent statements: ", df_opt['parents_length'].mean())
print("================================================")
# find suboptimal steps
df_in['count_sub'] = df_in.apply(lambda row: 1 if str(row['student_step']) in str(row['filtered_derivation_keys']) else 0, axis=1)
print("suboptimal steps: ", df_in['count_sub'].sum())

# suboptimal steps with depth==1 and complexity details
df_sub_1 = df_in[df_in['count_sub'] == 1].copy()
print("suboptimal steps: ", (df_sub_1.shape[0]/df.shape[0]))
print("================================================")
# suboptimal steps with depth 1
# complexity details
print("suboptimal steps with depth 1: ", (df_sub_1['student_depth']==1).sum()/df.shape[0])
print("\n")
print("mean complexity of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['student_complexity'].mean())
print("actual complexity of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['KG_complexity'].mean())
print("complexity gap of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['student_complexity'].mean() - df_sub_1[df_sub_1['student_depth']==1]['KG_complexity'].mean())
print("\n")
# distance details
print("mean distance of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['student_distance'].mean())
print("actual distance of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['KG_distance'].mean())
print("distance gap of suboptimal steps at depth==1: ", df_sub_1[df_sub_1['student_depth']==1]['student_distance'].mean() - df_sub_1[df_sub_1['student_depth']==1]['KG_distance'].mean())
print("================================================")
print("suboptimal steps with depth > 1: ", (df_sub_1['student_depth']>1).sum()/df.shape[0])
print("\n")
print("mean complexity of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_complexity'].mean())
print("actual complexity of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['KG_complexity'].mean())
print("complexity gap of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_complexity'].mean() - df_sub_1[df_sub_1['student_depth']>1]['KG_complexity'].mean())
print("\n")
print("mean depth of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_depth'].mean())
print("actual depth of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['KG_depth'].mean())
print("depth gap of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_depth'].mean() - df_sub_1[df_sub_1['student_depth']>1]['KG_depth'].mean())
print("\n")
print("mean distance of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_distance'].mean())
print("actual distance of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['KG_distance'].mean())
print("distance gap of suboptimal steps at depth>1: ", df_sub_1[df_sub_1['student_depth']>1]['student_distance'].mean() - df_sub_1[df_sub_1['student_depth']>1]['KG_distance'].mean())
print("================================================")
print("incorrect steps: ", (df_in['count_sub']==0).sum()/df.shape[0])
print("\n")
print("mean complexity of incorrect steps: ", df_in[df_in['count_sub']==0]['student_complexity'].mean())
print("actual complexity of incorrect steps: ", df_in[df_in['count_sub']==0]['KG_complexity'].mean())
print("complexity gap of incorrect steps: ", df_in[df_in['count_sub']==0]['student_complexity'].mean() - df_in[df_in['count_sub']==0]['KG_complexity'].mean())
print("\n")
print("mean depth of incorrect steps: ", df_in[df_in['count_sub']==0]['student_depth'].mean())
print("actual depth of incorrect steps: ", df_in[df_in['count_sub']==0]['KG_depth'].mean())
print("depth gap of incorrect steps: ", df_in[df_in['count_sub']==0]['student_depth'].mean() - df_in[df_in['count_sub']==0]['KG_depth'].mean())
print("\n")
print("mean distance of incorrect steps: ", df_in[df_in['count_sub']==0]['student_distance'].mean())
print("actual distance of incorrect steps: ", df_in[df_in['count_sub']==0]['KG_distance'].mean())
print("distance gap of incorrect steps: ", df_in[df_in['count_sub']==0]['student_distance'].mean() - df_in[df_in['count_sub']==0]['KG_distance'].mean())

print("================================================")

df_in['count_teacher'] = df_in.apply(lambda row: 1 if (row['student_update_step_new'] == row['KG_step_new']) & (row['student_update_rule'] == row['KG_rule']) else 0, axis=1)
teacher_correct = df_in['count_teacher'].sum()
print("teacher correct: ", teacher_correct)
post_teacher = (teacher_correct+pre_count)/df.shape[0]
print("post teacher feedback: ", post_teacher)

df_in['count_judge'] = df_in.apply(lambda row: 1 if (row['judge_student_update_step_new'] == row['KG_step_new']) & (row['judge_student_update_rule'] == row['KG_rule']) else 0, axis=1)
judge_correct = df_in['count_judge'].sum()
post_judge = (judge_correct+pre_count)/df.shape[0]
print("judge correct: ", judge_correct)
print("post judge feedback: ", post_judge)

df_in['count_ours'] = df_in.apply(lambda row: 1 if (row['ours_student_update_step_new'] == row['KG_step_new']) & (row['ours_student_update_rule'] == row['KG_rule']) else 0, axis=1)
ours_correct = df_in['count_ours'].sum()
post_ours = (ours_correct+pre_count)/df.shape[0]
print("ours correct: ", ours_correct)
print("post our feedback: ", post_ours)


print("================================================")
ecr_teacher = (teacher_correct)/(df.shape[0]-pre_count)
ecr_judge = (judge_correct)/(df.shape[0]-pre_count)
ecr_ours = (ours_correct)/(df.shape[0]-pre_count)

print("ecr_teacher: ", ecr_teacher)
print("ecr_judge: ", ecr_judge)
print("ecr_ours: ", ecr_ours)
# Out:
# ================================================
# Optimal number of steps:  128
# Optimal number of steps:  0.24806201550387597
# mean complexity of optimal steps:  1.7890625
# mean distance of optimal steps:  2.6640625
# ================================================
# suboptimal steps:  320
# suboptimal steps:  0.6201550387596899
# ================================================
# suboptimal steps with depth 1:  0.13372093023255813
#
#
# mean complexity of suboptimal steps at depth==1:  2.0
# actual complexity of suboptimal steps at depth==1:  3.550724637681159
# complexity gap of suboptimal steps at depth==1:  -1.5507246376811592
#
#
# mean distance of suboptimal steps at depth==1:  3.1884057971014492
# actual distance of suboptimal steps at depth==1:  3.0579710144927534
# distance gap of suboptimal steps at depth==1:  0.1304347826086958
# ================================================
# suboptimal steps with depth > 1:  0.48643410852713176
#
#
# mean complexity of suboptimal steps at depth>1:  1.792828685258964
# actual complexity of suboptimal steps at depth>1:  3.199203187250996
# complexity gap of suboptimal steps at depth>1:  -1.4063745019920317
#
#
# mean depth of suboptimal steps at depth>1:  2.8286852589641436
# actual depth of suboptimal steps at depth>1:  1.0
# depth gap of suboptimal steps at depth>1:  1.8286852589641436
#
#
# mean distance of suboptimal steps at depth>1:  2.9163346613545817
# actual distance of suboptimal steps at depth>1:  2.8804780876494025
# distance gap of suboptimal steps at depth>1:  0.03585657370517925
# ================================================
# incorrect steps:  0.13178294573643412
#
#
# mean complexity of incorrect steps:  3.5588235294117645
# actual complexity of incorrect steps:  4.514705882352941
# complexity gap of incorrect steps:  -0.9558823529411766
#
#
# mean depth of incorrect steps:  2.9558823529411766
# actual depth of incorrect steps:  1.0
# depth gap of incorrect steps:  1.9558823529411766
#
#
# mean distance of incorrect steps:  3.588235294117647
# actual distance of incorrect steps:  2.6176470588235294
# distance gap of incorrect steps:  0.9705882352941178
# ================================================
# teacher correct:  121
# post teacher feedback:  0.48255813953488375
# judge correct:  188
# post judge feedback:  0.6124031007751938
# ours correct:  262
# post our feedback:  0.7558139534883721
# ================================================
# ecr_teacher:  0.3118556701030928
# ecr_judge:  0.4845360824742268
# ecr_ours:  0.6752577319587629

# %% [markdown]
# # PNIR

# %%
# Count positive and negative instruction
P = (df_in["count_teacher"] == 1).sum()
N = (df_in["count_teacher"] == 0).sum()

# PNIR
pnir = N / P if P > 0 else float("inf")
print(f"P = {P}, N = {N}, Judge PNIR = {pnir:.3f}")


# Count positive and negative instruction
P = (df_in["count_judge"] == 1).sum()
N = (df_in["count_judge"] == 0).sum()

# PNIR
pnir = N / P if P > 0 else float("inf")
print(f"P = {P}, N = {N}, Judge PNIR = {pnir:.3f}")


# Count positive and negative instruction
P = (df_in["count_ours"] == 1).sum()
N = (df_in["count_ours"] == 0).sum()

# PNIR
pnir = N / P if P > 0 else float("inf")
print(f"P = {P}, N = {N}, Judge PNIR = {pnir:.3f}")
# Out:
# P = 121, N = 267, Judge PNIR = 2.207
# P = 188, N = 200, Judge PNIR = 1.064
# P = 262, N = 126, Judge PNIR = 0.481

# %% [markdown]
# # Manual Responses

# %%
df_in.loc[
    (df_in["count_student"] == 0) &
    (df_in["count_teacher"] == 0) &
    (df_in["count_judge"] == 0) &
    (df_in["count_ours"] == 1),
    [
        "givens", "intermediate_expressions", "conclusion", "KG_step",
        "KG_plan", "student_reasoning", "student_candidates",
       "teacher_feedback", 'judge_feedback', "final_feedback_ours"
    ]
].tail(30).to_clipboard(index=False)

# %% [markdown]
# # whether the agents were able to assess the correctness

# %%
# optimal steps assessment
print("next_step_correctness_x:")
print(df_opt[df_opt['count_student'] == 1][['next_step_correctness_x']].value_counts())
print("\nnext_step_correctness_y:")
print(df_opt[df_opt['count_student'] == 1][['next_step_correctness_y']].value_counts())
print("\nnext_step_correctness_ours:")
print(df_opt[df_opt['count_student'] == 1][['next_step_correctness_ours']].value_counts())


# Value counts for next_step_correctness columns where count_student == 1
# Filter rows where count_student == 1
df_student_correct = df_opt[df_opt['count_student'] == 1]

# Print total number of rows where count_student == 1
print(f"Total number of rows where count_student == 1: {len(df_student_correct)}")
 

# suboptimal steps assessment
print("next_step_correctness_x:")
print(df_in[df_in['count_sub'] == 1][['next_step_correctness_x']].value_counts())
print("\nnext_step_correctness_y:")
print(df_in[df_in['count_sub'] == 1][['next_step_correctness_y']].value_counts())
print("\nnext_step_correctness_ours:")
print(df_in[df_in['count_sub'] == 1][['next_step_correctness_ours']].value_counts())


# Value counts for next_step_correctness columns where count_student == 1
# Filter rows where count_student == 1
df_student_suboptimal = df_in[df_in['count_sub'] == 1]

# Print total number of rows where count_student == 1
print(f"Total number of rows where count_sub == 1: {len(df_student_suboptimal)}")
# Out:
# next_step_correctness_x:
# next_step_correctness_x
# Correct                    127
# Suboptimal                   1
# Name: count, dtype: int64
#
# next_step_correctness_y:
# next_step_correctness_y
# Correct                    127
# Suboptimal                   1
# Name: count, dtype: int64
#
# next_step_correctness_ours:
# next_step_correctness_ours
# Correct                       127
# Suboptimal                      1
# Name: count, dtype: int64
# Total number of rows where count_student == 1: 128
# next_step_correctness_x:
# next_step_correctness_x
# Incorrect                  170
# Suboptimal                 116
# Correct                     34
# Name: count, dtype: int64
#
# next_step_correctness_y:
# next_step_correctness_y
# Incorrect                  164
# Suboptimal                 137
# Correct                     19
# Name: count, dtype: int64
#
# next_step_correctness_ours:
# next_step_correctness_ours
# Incorrect                     193
# Suboptimal                    121
# Correct                         6
# Name: count, dtype: int64
# Total number of rows where count_sub == 1: 320

# %% [markdown]
# # Teacher rule accuracy

# %%
import pandas as pd

# Binary correctness
df["teacher_rule_correct"] = (df["teacher_rule"] == df["KG_rule"]).astype(int)

# Total teacher rule accuracy
total_teacher_rule_accuracy = df["teacher_rule_correct"].mean()

print(f"Total Teacher Rule Accuracy: {total_teacher_rule_accuracy:.3f}")


# Binary correctness per instance
df["teacher_rule_correct"] = (df["teacher_rule"] == df["KG_rule"]).astype(int)

# Accuracy per gold rule
teacher_rule_accuracy = (
    df.groupby("KG_rule")
      .agg(
          total_instances=("teacher_rule_correct", "count"),
          correct_predictions=("teacher_rule_correct", "sum"),
          accuracy=("teacher_rule_correct", "mean")
      )
      .reset_index()
      .sort_values("total_instances", ascending=False)
)

print(teacher_rule_accuracy)
teacher_rule_confusion = (
    df.groupby(["KG_rule", "teacher_rule"])
      .agg(
          count=("teacher_rule", "size"),
          correct=("teacher_rule_correct", "sum")
      )
      .reset_index()
      .sort_values(["KG_rule", "count"], ascending=[True, False])
)

# print(teacher_rule_confusion)
# Out:
# Total Teacher Rule Accuracy: 0.601
#    KG_rule  total_instances  correct_predictions  accuracy
# 14    Simp               90                   78  0.866667
# 0      Add               61                   47  0.770492
# 12      MP               61                   47  0.770492
# 6       DS               53                   24  0.452830
# 13      MT               40                   22  0.550000
# 11    Impl               38                   20  0.526316
# 2       CP               36                   12  0.333333
# 5       DN               31                   18  0.580645
# 1       CD               27                    3  0.111111
# 7      DeM               21                    8  0.380952
# 10      HS               21                   12  0.571429
# 4     Conj               14                   13  0.928571
# 3      Com               12                    4  0.333333
# 9    Equiv                7                    0  0.000000
# 8     Dist                2                    2  1.000000
# 15     nan                2                    0  0.000000

# %% [markdown]
# # Student Rule Accuracy

# %%
# Initial correctness
df["init_correct"] = (df["student_rule"] == df["KG_rule"]).astype(int)

# Correction indicators (only meaningful if init_correct == 0)
df["tutor_corrected"] = (
    (df["init_correct"] == 0) &
    (df["student_update_rule"] == df["KG_rule"])
).astype(int)

df["teacher_corrected"] = (
    (df["init_correct"] == 0) &
    (df["judge_student_update_rule"] == df["KG_rule"])
).astype(int)

df["judge_corrected"] = (
    (df["init_correct"] == 0) &
    (df["ours_student_update_rule"] == df["KG_rule"])
).astype(int)

rule_correction = (
    df[df["init_correct"] == 0]  # only initially wrong
    .groupby("KG_rule")
    .agg(
        total_errors=("KG_rule", "count"),
        tutor_fixed=("tutor_corrected", "sum"),
        teacher_fixed=("teacher_corrected", "sum"),
        judge_fixed=("judge_corrected", "sum"),
    )
)

# Convert to rates
rule_correction["tutor_rate"] = rule_correction["tutor_fixed"] / rule_correction["total_errors"]
rule_correction["teacher_rate"] = rule_correction["teacher_fixed"] / rule_correction["total_errors"]
rule_correction["judge_rate"] = rule_correction["judge_fixed"] / rule_correction["total_errors"]

rule_correction = rule_correction.sort_values("total_errors", ascending=False)
print(rule_correction)

resistant_rules = rule_correction[
    rule_correction["judge_rate"] < 0.25
].sort_values("judge_rate")

print(resistant_rules)

persistent_confusion = (
    df[(df["init_correct"] == 0) &
       (df["ours_student_update_rule"] != df["KG_rule"])]
    .groupby(["KG_rule", "ours_student_update_rule"])
    .size()
    .reset_index(name="count")
    .sort_values("count", ascending=False)
)
print(persistent_confusion)
# Out:
#          total_errors  tutor_fixed  teacher_fixed  judge_fixed  tutor_rate  \
# KG_rule
# Simp               65           43             53           60    0.661538
# Add                37           19             24           32    0.513514
# Impl               33            7              9           23    0.212121
# CP                 30            9             11           20    0.300000
# MT                 26           10             22           23    0.384615
# CD                 25            8             16           22    0.320000
# DN                 25           10             18           22    0.400000
# DS                 24            5             18           23    0.208333
# MP                 24           11             19           18    0.458333
# HS                 13            6              9           13    0.461538
# Com                12            2              2            3    0.166667
# DeM                12            5              7            8    0.416667
# Equiv               6            3              5            4    0.500000
# Conj                5            4              4            5    0.800000
# Dist                2            0              0            1    0.000000
# nan                 2            0              0            0    0.000000
#
#          teacher_rate  judge_rate
# KG_rule
# Simp         0.815385    0.923077
# Add          0.648649    0.864865
# Impl         0.272727    0.696970
# CP           0.366667    0.666667
# MT           0.846154    0.884615
# CD           0.640000    0.880000
# DN           0.720000    0.880000
# DS           0.750000    0.958333
# MP           0.791667    0.750000
# HS           0.692308    1.000000
# Com          0.166667    0.250000
# DeM          0.583333    0.666667
# Equiv        0.833333    0.666667
# Conj         0.800000    1.000000
# Dist         0.000000    0.500000
# nan          0.000000    0.000000
#          total_errors  tutor_fixed  teacher_fixed  judge_fixed  tutor_rate  \
# KG_rule
# nan                 2            0              0            0         0.0
#
#          teacher_rate  judge_rate
# KG_rule
# nan               0.0         0.0
#    KG_rule ours_student_update_rule  count
# 7       CP                   Contra      7
# 12     Com                     Comm      7
# 40    Simp                    Equiv      4
# 34      MP                       DS      2
# 26    Impl                       DS      2
# 5       CD                       HS      2
# 38      MT      NoImprovementNeeded      2
# 35      MP      NoImprovementNeeded      2
# 29    Impl                       MT      2
# 31    Impl    NegationofConditional      1
# 25    Impl                       CP      1
# 27    Impl                      Imp      1
# 28    Impl                       MP      1
# 30    Impl                  NegCond      1
# 0      Add                      DeM      1
# 32    Impl                     Simp      1
# 33      MP                      Add      1
# 23   Equiv                   Bicond      1
# 36      MP                     Simp      1
# 37      MT                       CP      1
# 39    Simp                       DN      1
# 41     nan                    Equiv      1
# 24   Equiv               BicondElim      1
# 21     DeM      NoImprovementNeeded      1
# 22    Dist      NoImprovementNeeded      1
# 11     Com                       CP      1
# 2      Add                     Reit      1
# 3      Add                  Restate      1
# 4      Add                     Simp      1
# 6       CD      NoImprovementNeeded      1
# 8       CP                       DS      1
# 9       CP                    Equiv      1
# 10      CP                       MT      1
# 13     Com                     Impl      1
# 1      Add      NoImprovementNeeded      1
# 14      DN                   Contra      1
# 15      DN                      DeM      1
# 16      DN      NoImprovementNeeded      1
# 17      DS                     Simp      1
# 18     DeM                       CP      1
# 19     DeM                      Imp      1
# 20     DeM                     Impl      1
# 42     nan      NoImprovementNeeded      1

# %% [markdown]
# # Feedback hurts or improve

# %%
# rows where count_student == 0 and count_ours == 0
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_teacher'] == 1) ]

print('imrpoved steps teacher: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
# in count number of rows in df_degrading, rows where teacher_rule == KG_rule
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student step new == KG_step new: ',df_degrading[df_degrading['student_step_new'] == df_degrading['KG_step_new']].shape[0])
print('student rule == KG_rule: ',df_degrading[df_degrading['student_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_judge'] == 1) ]
print('teacher improved steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher_rule == kg_rule: ', df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_ours'] == 1) ]
print('ours improved steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) &  (df_in['count_teacher'] == 0) & (df_in['count_ours'] == 1) ]
print('teacher degrade, ours improved steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) &  (df_in['count_judge'] == 0) & (df_in['count_ours'] == 1) ]
print('judge degrade, ours improved steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) &  (df_in['count_teacher'] == 1) & (df_in['count_ours'] == 1) ]
print('teacher improved, ours improved steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
# Out:
# imrpoved steps teacher:  121
# steps complexity:  2.049586776859504
# teacher rule == KG_rule:  95
# student step new == KG_step new:  0
# student rule == KG_rule:  20
# student rule == teacher rule and != KG_rule:  6
# student step or rule == KG_step or rule:  20
# --------------------------------
# teacher improved steps:  188
# steps complexity:  2.265957446808511
# student step or rule == KG_step or rule:  40
# teacher_rule == kg_rule:  107
# student rule == teacher rule and != KG_rule:  31
# --------------------------------
# ours improved steps:  262
# steps complexity:  2.6564885496183206
# student step or rule == KG_step or rule:  53
# teacher rule == KG_rule:  140
# student rule == teacher rule and != KG_rule:  46
# --------------------------------
# teacher degrade, ours improved steps:  150
# steps complexity:  3.1733333333333333
# student step or rule == KG_step or rule:  34
# teacher rule == KG_rule:  49
# student rule == teacher rule and != KG_rule:  41
# --------------------------------
# judge degrade, ours improved steps:  84
# steps complexity:  3.6666666666666665
# student step or rule == KG_step or rule:  14
# teacher rule == KG_rule:  36
# student rule == teacher rule and != KG_rule:  17
# --------------------------------
# teacher improved, ours improved steps:  112
# steps complexity:  1.9642857142857142
# student step or rule == KG_step or rule:  19
# teacher rule == KG_rule:  91
# student rule == teacher rule and != KG_rule:  5

# %%
# rows where count_student == 0 and count_ours == 0
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_teacher'] == 0) ]

print('degraded steps teacher: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
# in count number of rows in df_degrading, rows where teacher_rule == KG_rule
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student step new == KG_step new: ',df_degrading[df_degrading['student_step_new'] == df_degrading['KG_step_new']].shape[0])
print('student rule == KG_rule: ',df_degrading[df_degrading['student_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_judge'] == 0) ]
print('judge degraded steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher_rule == kg_rule: ', df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) & (df_in['count_ours'] == 0) ]
print('ours degraded steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
print('--------------------------------')
df_degrading = df_in[(df_in['count_student'] == 0) &  (df_in['count_teacher'] == 0) & (df_in['count_ours'] == 0) ]
print('teacher degrade, ours degraded steps: ', df_degrading.shape[0])
print('steps complexity: ', df_degrading['KG_complexity'].mean())
print('student step or rule == KG_step or rule: ',df_degrading[(df_degrading['student_step_new'] == df_degrading['KG_step_new']) | (df_degrading['student_rule'] == df_degrading['KG_rule'])].shape[0])
print('teacher rule == KG_rule: ',df_degrading[df_degrading['teacher_rule'] == df_degrading['KG_rule']].shape[0])
print('student rule == teacher rule and != KG_rule: ',df_degrading[(df_degrading['student_rule'] == df_degrading['teacher_rule']) & (df_degrading['teacher_rule'] != df_degrading['KG_rule'])].shape[0])
# Out:
# degraded steps teacher:  267
# steps complexity:  4.146067415730337
# teacher rule == KG_rule:  88
# student step new == KG_step new:  15
# student rule == KG_rule:  27
# student rule == teacher rule and != KG_rule:  49
# student step or rule == KG_step or rule:  42
# --------------------------------
# judge degraded steps:  200
# steps complexity:  4.645
# student step or rule == KG_step or rule:  22
# teacher_rule == kg_rule:  76
# student rule == teacher rule and != KG_rule:  24
# --------------------------------
# ours degraded steps:  126
# steps complexity:  5.23015873015873
# student step or rule == KG_step or rule:  9
# teacher rule == KG_rule:  43
# student rule == teacher rule and != KG_rule:  9
# --------------------------------
# teacher degrade, ours degraded steps:  117
# steps complexity:  5.3931623931623935
# student step or rule == KG_step or rule:  8
# teacher rule == KG_rule:  39
# student rule == teacher rule and != KG_rule:  8

# %%
# df_in[(df_in['count_student'] == 0) & (df_in['count_teacher'] == 0)][['KG_step_new', 'KG_rule', 'student_step_new', 'student_rule', 'teacher_rule', 'student_update_step_new', 'student_update_rule']]

# #judge degrading steps and feedback
# df_in[(df_in['count_student'] == 0) & (df_in['count_teacher'] == 0) & (df_in['count_judge'] == 1) & (df_in['count_ours'] == 1)][['KG_step_new', 'KG_rule', 'student_step_new', 'student_rule','student_update_step_new', 'student_update_rule','judge_student_update_step_new', 'judge_student_update_rule', 'ours_student_update_step_new', 'ours_student_update_rule','count_sub','judge_feedback', 'teacher_feedback','final_feedback_ours']]

# %% [markdown]
# # Responses for evaluations

# %%
df_in.loc[
    (df_in["count_student"] == 0) &
    (df_in["count_teacher"] == 0) &
    (df_in["count_judge"] == 0) &
    (df_in["count_ours"] == 1),
    [
        "givens", "intermediate_expressions", "conclusion", "KG_step",
        "KG_plan", "student_reasoning", "student_candidates",
       "teacher_feedback", 'judge_feedback', "final_feedback_ours"
    ]
].head(50).to_clipboard(index=False)

# %%
df_in.loc[
    (df_in["count_student"] == 0) &
    (df_in["count_teacher"] == 0) &
    (df_in["count_judge"] == 0) &
    (df_in["count_ours"] == 1),
    [
        "givens", "intermediate_expressions", "conclusion", "KG_step",
        "KG_plan", 'student_step_new', 'count_sub','next_step_correctness_x', 'next_step_correctness_y', 'next_step_correctness_ours',"student_reasoning", "student_candidates",
       "teacher_feedback", 'judge_feedback', "final_feedback_ours"
    ]
]
# .head(50).to_clipboard(index=False)
# Out:
#                                                       givens  \
# 38                        ['((-O+L)>(M*-N))', '-O', '(K>N)']
# 63                ['-U', '((B>U)*(L+C))', '-L', '((C+D)>H)']
# 69              ['((S>D)+I)', '((-S+Q)>Y)', '-D', '(-D>-I)']
# 81              ['((S>D)+I)', '((-S+Q)>Y)', '-D', '(-D>-I)']
# 101     ['(C*-F)', '(-C>F)', '(-F>-(-K+-Z))', '(D>(-K+-Z))']
# 103     ['(C*-F)', '(-C>F)', '(-F>-(-K+-Z))', '(D>(-K+-Z))']
# 115        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 119        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 129        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 132        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 138        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 144        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 152        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 156        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 162        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 163        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 164        ['((S>Y)+(I*Q))', '((I*Q)>D)', '-D', '((S>Y)>D)']
# 167         ['(K>R)', '(-S*(-R+P))', '(O>S)', '((-S+T)>-P)']
# 168         ['(K>R)', '(-S*(-R+P))', '(O>S)', '((-S+T)>-P)']
# 174         ['(K>R)', '(-S*(-R+P))', '(O>S)', '((-S+T)>-P)']
# 177  ['((R*N)>O)', '(-O*(-W>A))', '((U>K)+(R*N))', '(K>-W)']
# 204                              ['(S+B)', '(B>D)', '(S>G)']
# 207                              ['(S+B)', '(B>D)', '(S>G)']
# 211                              ['(S+B)', '(B>D)', '(S>G)']
# 214                              ['(S+B)', '(B>D)', '(S>G)']
# 251         ['((A>B)*(-D>F))', '(A+-D)', '(-A>(D+G))', '-A']
# 255         ['((A>B)*(-D>F))', '(A+-D)', '(-A>(D+G))', '-A']
# 260         ['((A>B)*(-D>F))', '(A+-D)', '(-A>(D+G))', '-A']
# 268         ['((A>B)*(-D>F))', '(A+-D)', '(-A>(D+G))', '-A']
# 273          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 279          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 299          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 302          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 303          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 304          ['(Z>(-Y>X))', '(Z*-W)', '(W+(T>S))', '(-Y+T)']
# 311          ['(-G>Q)', '((Q>A)*P)', '(H>-B)', '(P>(-G+H))']
# 344                                      ['-(G*A)', '(B>A)']
# 352                                     ['-(-G*B)', '(G>D)']
# 356                                     ['-(-G*B)', '(G>D)']
# 377                             ['(K>M)', '(Z>R)', '-(K>R)']
# 385                             ['(K>M)', '(Z>R)', '-(K>R)']
# 391                             ['(K>M)', '(Z>R)', '-(K>R)']
# 392                             ['(K>M)', '(Z>R)', '-(K>R)']
# 393                             ['(K>M)', '(Z>R)', '-(K>R)']
# 405                            ['((A>-B)+C)', '-C', '(D+B)']
# 407                            ['((A>-B)+C)', '-C', '(D+B)']
# 408                            ['((A>-B)+C)', '-C', '(D+B)']
# 410                            ['((A>-B)+C)', '-C', '(D+B)']
# 411                            ['((A>-B)+C)', '-C', '(D+B)']
# 416                           ['(-(K*-N)>W)', '-L', '(K>L)']
# 430                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 433                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 441                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 442                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 444                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 449                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 454                           ['(J>H)', '(-W>(-H*-F))', 'J']
# 463                            ['(C=-J)', '(C+-N)', '(N>C)']
# 473                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 474                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 477                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 479                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 484                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 489                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 491                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 496                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 503                          ['(Y=P)', '(-Y>-C)', '(-P=-C)']
# 509                           ['(B=-J)', '(-N+J)', '(B+-N)']
# 511                           ['(B=-J)', '(-N+J)', '(B+-N)']
# 515                           ['(B=-J)', '(-N+J)', '(B+-N)']
#
#                                                                                                                intermediate_expressions  \
# 38                                                                         ['(-(-O+L)+(M*-N))', '((--O*-L)+(M*-N))', '((O*-L)+(M*-N))']
# 63                                                                                                           ['(B>U)', '(-U>-B)', '-B']
# 69   ['((-S+D)+I)', '(--I>--D)', '(I>--D)', '(I>D)', '-I', '(-(-S+Q)+Y)', '((--S*-Q)+Y)', '((S*-Q)+Y)', '(Y+(S*-Q))', '((Y+S)*(Y+-Q))']
# 81                                                                       ['-I', '(-(S>D)>I)', '--(S>D)', '(S>D)', '-S', '(-Y>-(-S+Q))']
# 101                                                                                      ['-F', '-(-K+-Z)', '-D', '(-F>--C)', '(-F>C)']
# 103                                                                                                                  ['(-F>--C)', '-F']
# 115                                                      ['-(I*Q)', '-(S>Y)', '(I*Q)', 'D', '(S>Y)', '-(-S+Y)', '(--S*-Y)', '--S', 'S']
# 119                                                                      ['-(S>Y)', '-(I*Q)', '(S>Y)', '-(-S+Y)', '(--S*-Y)', '(S*-Y)']
# 129                                         ['-(S>Y)', '-(I*Q)', '(-(S>Y)>(I*Q))', '--(S>Y)', '(S>Y)', '-(-S+Y)', '(--S*-Y)', '(S*-Y)']
# 132                                                           ['-(I*Q)', '-(S>Y)', '(I*Q)', 'D', '(S>Y)', '-(-S+Y)', '(--S*-Y)', '--S']
# 138                                                                                          ['-(S>Y)', '(-(S>Y)>(I*Q))', '(I*Q)', 'D']
# 144                                                                                              ['-(S>Y)', '-(I*Q)', '(I*Q)', '(S>Y)']
# 152                                                                                             ['-(I*Q)', '(S>Y)', '-(S>Y)', '(-S+Y)']
# 156                                                                                    ['-(I*Q)', '(-(S>Y)>(I*Q))', '--(S>Y)', '(S>Y)']
# 162                     ['-(I*Q)', '(-(S>Y)>(I*Q))', '--(S>Y)', '(S>Y)', 'D', '(-S+Y)', '-(S>Y)', '-(-S+Y)', '(--S*-Y)', '(S*-Y)', 'S']
# 163                                                                                              ['-(S>Y)', '(I*Q)', 'D', '(-(S>Y)+D)']
# 164                                                         ['-(S>Y)', '-(I*Q)', '((I*Q)+(S>Y))', '(S>Y)', '-(-S+Y)', '(--S*-Y)', '-Y']
# 167                                                                            ['-S', '-O', '(-R+P)', '(R>P)', '(K>P)', '(-S+T)', '-P']
# 168                                                                                                                              ['-S']
# 174                                                                                                              ['-S', '-O', '(-R+P)']
# 177                                                                                                  ['-O', '-(R*N)', '(-(U>K)>(R*N))']
# 204                                                                                                          ['(B+S)', '((S+B)>(G+D))']
# 207                                                                                                                          ['(-S>B)']
# 211                                                                                                    ['(-S>B)', '(-S>D)', '(-D>--S)']
# 214                                                                                                                ['(-B+D)', '(-S+G)']
# 251                                                                                                          ['(-A>-D)', '-D', '(D+G)']
# 255                                                                                                     ['(D+G)', '-D', 'G', '(-A>-D)']
# 260                                                                                      ['(-A>-D)', '-D', '(D+G)', '(-D>F)', '(-A>F)']
# 268                                                                                                      ['-D', '(D+G)', '(-D>G)', 'G']
# 273                                                                          ['Z', '(-Y>X)', '-W', '(T>S)', '((T+-Y)>(S+X))', '(T+-Y)']
# 279                                                                                                 ['-W', '(T>S)', '(-Z+(-Y>X))', 'Z']
# 299                                                    ['-W', '(T>S)', '(-Z+(-Y>X))', 'Z', '--Z', '(-Y>X)', '(Y>T)', '(Y>S)', '(-Y+S)']
# 302     ['-W', '(T>S)', 'Z', '(-Y>X)', '(Y>T)', '(Y>S)', '((-Y+Y)>(X+S))', '(-(-Y+Y)+(X+S))', '((--Y*-Y)+(X+S))', '(-X>--Y)', '(-X>Y)']
# 303                                                                                           ['Z', '(-Y>X)', '-W', '(T>S)', '(-S>-T)']
# 304                                                                                           ['Z', '-W', '(-Y>X)', '(T>S)', '(--Y>T)']
# 311                                                                                                  ['P', '(Q>A)', '(-G>A)', '(-G+H)']
# 344                                                                                                              ['(-G+-A)', '(-A>-B)']
# 352                                                                               ['(--G+-B)', '(G+-B)', '(-G+D)', '(-G>-B)', '(-B+G)']
# 356                                                                                 ['(--G+-B)', '(-G+D)', '(G+-B)', '(-B+G)', '(B>G)']
# 377                                                                                                              ['(-M>-K)', '-(-K+R)']
# 385                                                                ['(-K+M)', '(M+-K)', '(-M>-K)', '((-M+Z)>(-K+R))', '((-M+Z)>(K>R))']
# 391                                                   ['-(-K+R)', '(-M>-K)', '(--K*-R)', '(K*-R)', 'K', '(-Z+R)', '-R', '-Z', '(M+-K)']
# 392                                                                                                                   ['((Z+K)>(R+M))']
# 393                                                                                                                   ['((K+Z)>(M+R))']
# 405                                                                                                    ['(A>-B)', '(--B>-A)', '(B>-A)']
# 407                                                                                                                ['(A>-B)', '(-D>B)']
# 408                                                                                        ['(A>-B)', '(-D>B)', '(--B>-A)', '(-B>--D)']
# 410                                                                                                            ['(C+(A>-B))', '(A>-B)']
# 411                                                                            ['(C+(A>-B))', '(A>-B)', '(-D>B)', '(-B>--D)', '(-B>D)']
# 416                                                                                                      ['((-K+--N)>W)', '((-K+N)>W)']
# 430                                                                                                       ['H', '(H+J)', '(-W>-(H+F))']
# 433                                                                                                           ['H', '(H+F)', '--(H+F)']
# 441                                                                                               ['H', '(H+F)', '--(H+F)', '-(-H*-F)']
# 442                                                                                  ['H', '(H+F)', '(--H+F)', '(--H+--F)', '-(-H*-F)']
# 444                                                                                                                      ['H', '(H+F)']
# 449                                                                                            ['H', '(H+F)', '(--H+F)', '(-W>-(H+F))']
# 454                                                                                                                ['H', '(W+(-H*-F))']
# 463                                                                                  ['((C>-J)*(-J>C))', '(C>-J)', '(-C>-N)', '(-N+C)']
# 473                                                                          ['((Y>P)*(P>Y))', '((-P>-C)*(-C>-P))', '(-C>-P)', '(Y>P)']
# 474                                                  ['((-P>-C)*(-C>-P))', '((Y>P)*(P>Y))', '(-C>-P)', '(--P>--C)', '(P>--C)', '(P>C)']
# 477                                                                          ['((Y>P)*(P>Y))', '(Y>P)', '((-P>-C)*(-C>-P))', '(-P>-C)']
# 479                                                                ['((Y>P)*(P>Y))', '(Y>P)', '((-P>-C)*(-C>-P))', '((-C>-P)*(-P>-C))']
# 484                                                                                   ['((-P>-C)*(-C>-P))', '((Y>P)*(P>Y))', '(-C>-P)']
# 489                                                                                                    ['((-P>-C)*(-C>-P))', '(-C>-P)']
# 491        ['((-P>-C)*(-C>-P))', '(--C>--Y)', '((Y>P)*(P>Y))', '(C>--Y)', '(C>Y)', '(-C>-P)', '(--P>--C)', '(P>--C)', '(P>C)', '(P>Y)']
# 496                                                                                   ['((Y>P)*(P>Y))', '((-P>-C)*(-C>-P))', '(-P>-C)']
# 503                                                             ['((Y>P)*(P>Y))', '((-P>-C)*(-C>-P))', '(P>Y)', '(-C>-P)', '(--P>--C)']
# 509                                                                                                       ['((B>-J)*(-J>B))', '(J+-N)']
# 511                                                                                             ['((B>-J)*(-J>B))', '(B>-J)', '(J+-N)']
# 515                                                                        ['((B>-J)*(-J>B))', '(B>-J)', '(-J>B)', '(-B+-J)', '(-N+B)']
#
#     conclusion          KG_step  \
# 38          -K           (-O+L)
# 63      (-B*H)            (L+C)
# 69           Y            (S>D)
# 81           Y           (-S+Q)
# 101    (-C+-D)                C
# 103    (-C+-D)    (-(-K+-Z)>-D)
# 115          Y            (D+Y)
# 119          Y            (I*Q)
# 129          Y            (I*Q)
# 132          Y            (D+S)
# 138          Y            (D+Y)
# 144          Y          -(-S+Y)
# 152          Y          -(-S+Y)
# 156          Y           -(S>Y)
# 162          Y              --S
# 163          Y            (D+Y)
# 164          Y           (S*-Y)
# 167    (-K*-O)               -R
# 168    (-K*-O)           (-R+P)
# 174    (-K*-O)            (R>P)
# 177      (U>A)          --(U>K)
# 204      (D+G)    ((B+S)>(D+G))
# 207      (D+G)           (-S>D)
# 211      (D+G)           (-D>S)
# 214      (D+G)    ((B+S)>(D+G))
# 251  ((B+F)*G)           (-D>F)
# 255  ((B+F)*G)           (-D>F)
# 260  ((B+F)*G)                F
# 268  ((B+F)*G)           (-D>F)
# 273      (X+S)   ((-Y+T)>(X+S))
# 279      (X+S)              --Z
# 299      (X+S)         (-X>--Y)
# 302      (X+S)           (-X>S)
# 303      (X+S)   ((-Y+T)>(X+S))
# 304      (X+S)            (Y>T)
# 311     (A+-B)  ((-G+H)>(A+-B))
# 344     (G>-B)           (G>-A)
# 352     (-B+D)            (B>G)
# 356     (-B+D)            (B>D)
# 377     (M*-Z)  ((-M+Z)>(-K+R))
# 385     (M*-Z)          -(-M+Z)
# 391     (M*-Z)              --K
# 392     (M*-Z)          (-M>-K)
# 393     (M*-Z)          (-M>-K)
# 405    (-D>-A)           (-D>B)
# 407    (-D>-A)         (--B>-A)
# 408    (-D>-A)           (B>-A)
# 410    (-D>-A)           (-D>B)
# 411    (-D>-A)            (A>D)
# 416          W      (-(-K+N)+W)
# 430          W        ((H+F)>W)
# 433          W         -(-H*-F)
# 441          W              --W
# 442          W              --W
# 444          W          --(H+F)
# 449          W          --(H+F)
# 454          W  ((W+-H)*(W+-F))
# 463     (N>-J)  ((-J>C)*(C>-J))
# 473      (Y>C)            (P>C)
# 474      (Y>C)            (Y>P)
# 477      (Y>C)          (-C>-P)
# 479      (Y>C)          (-C>-P)
# 484      (Y>C)            (P>C)
# 489      (Y>C)            (P>C)
# 491      (Y>C)          (--P>C)
# 496      (Y>C)          (-C>-P)
# 503      (Y>C)            (P>C)
# 509     (B>-N)          (-J>-N)
# 511     (B>-N)          (-J>-N)
# 515     (B>-N)            (N>B)
#
#                                                                                 KG_plan  \
# 38                                       Derive (-O+L) from -O using the Addition rule.
# 63                       Derive (L+C) from ((B>U)*(L+C)) using the Simplification rule.
# 69             Derive (S>D) from ((S>D)+I) and -I using the Disjunctive Syllogism rule.
# 81                                       Derive (-S+Q) from -S using the Addition rule.
# 101                                 Derive C from (C*-F) using the Simplification rule.
# 103                Derive (-(-K+-Z)>-D) from (D>(-K+-Z)) using the Contrapositive rule.
# 115                                        Derive (D+Y) from D using the Addition rule.
# 119    Derive (I*Q) from ((S>Y)+(I*Q)) and -(S>Y) using the Disjunctive Syllogism rule.
# 129    Derive (I*Q) from ((S>Y)+(I*Q)) and -(S>Y) using the Disjunctive Syllogism rule.
# 132                                        Derive (D+S) from D using the Addition rule.
# 138                                        Derive (D+Y) from D using the Addition rule.
# 144                              Derive -(-S+Y) from -(S>Y) using the Implication rule.
# 152                              Derive -(-S+Y) from -(S>Y) using the Implication rule.
# 156                   Derive -(S>Y) from ((S>Y)>D) and -D using the Modus Tollens rule.
# 162                             Derive --S from (--S*-Y) using the Simplification rule.
# 163                                        Derive (D+Y) from D using the Addition rule.
# 164                         Derive (S*-Y) from (--S*-Y) using the Double Negation rule.
# 167                  Derive -R from (-R+P) and -P using the Disjunctive Syllogism rule.
# 168                       Derive (-R+P) from (-S*(-R+P)) using the Simplification rule.
# 174                                Derive (R>P) from (-R+P) using the Implication rule.
# 177         Derive --(U>K) from (-(U>K)>(R*N)) and -(R*N) using the Modus Tollens rule.
# 204      Derive ((B+S)>(D+G)) from (B>D) and (S>G) using the Constructive Dilemma rule.
# 207          Derive (-S>D) from (-S>B) and (B>D) using the Hypothetical Syllogism rule.
# 211                         Derive (-D>S) from (-D>--S) using the Double Negation rule.
# 214      Derive ((B+S)>(D+G)) from (B>D) and (S>G) using the Constructive Dilemma rule.
# 251                    Derive (-D>F) from ((A>B)*(-D>F)) using the Simplification rule.
# 255                    Derive (-D>F) from ((A>B)*(-D>F)) using the Simplification rule.
# 260                            Derive F from (-D>F) and -D using the Modus Ponens rule.
# 268                    Derive (-D>F) from ((A>B)*(-D>F)) using the Simplification rule.
# 273    Derive ((-Y+T)>(X+S)) from (-Y>X) and (T>S) using the Constructive Dilemma rule.
# 279                                   Derive --Z from Z using the Double Negation rule.
# 299                          Derive (-X>--Y) from (-Y>X) using the Contrapositive rule.
# 302          Derive (-X>S) from (-X>Y) and (Y>S) using the Hypothetical Syllogism rule.
# 303    Derive ((-Y+T)>(X+S)) from (-Y>X) and (T>S) using the Constructive Dilemma rule.
# 304                                Derive (Y>T) from (-Y+T) using the Implication rule.
# 311  Derive ((-G+H)>(A+-B)) from (-G>A) and (H>-B) using the Constructive Dilemma rule.
# 344                              Derive (G>-A) from (-G+-A) using the Implication rule.
# 352                                Derive (B>G) from (-B+G) using the Implication rule.
# 356            Derive (B>D) from (B>G) and (G>D) using the Hypothetical Syllogism rule.
# 377  Derive ((-M+Z)>(-K+R)) from (-M>-K) and (Z>R) using the Constructive Dilemma rule.
# 385         Derive -(-M+Z) from ((-M+Z)>(K>R)) and -(K>R) using the Modus Tollens rule.
# 391                             Derive --K from (--K*-R) using the Simplification rule.
# 392                            Derive (-M>-K) from (K>M) using the Contrapositive rule.
# 393                            Derive (-M>-K) from (K>M) using the Contrapositive rule.
# 405                                Derive (-D>B) from (D+B) using the Implication rule.
# 407                          Derive (--B>-A) from (A>-B) using the Contrapositive rule.
# 408                         Derive (B>-A) from (--B>-A) using the Double Negation rule.
# 410                                Derive (-D>B) from (D+B) using the Implication rule.
# 411          Derive (A>D) from (-B>D) and (A>-B) using the Hypothetical Syllogism rule.
# 416                      Derive (-(-K+N)+W) from ((-K+N)>W) using the Implication rule.
# 430                    Derive ((H+F)>W) from (-W>-(H+F)) using the Contrapositive rule.
# 433                         Derive -(-H*-F) from --(H+F) using the DeMorgan's Law rule.
# 441             Derive --W from (-W>(-H*-F)) and -(-H*-F) using the Modus Tollens rule.
# 442             Derive --W from (-W>(-H*-F)) and -(-H*-F) using the Modus Tollens rule.
# 444                           Derive --(H+F) from (H+F) using the Double Negation rule.
# 449                           Derive --(H+F) from (H+F) using the Double Negation rule.
# 454                Derive ((W+-H)*(W+-F)) from (W+(-H*-F)) using the Distributive rule.
# 463             Derive ((-J>C)*(C>-J)) from ((C>-J)*(-J>C)) using the Commutative rule.
# 473                            Derive (P>C) from (-C>-P) using the Contrapositive rule.
# 474                      Derive (Y>P) from ((Y>P)*(P>Y)) using the Simplification rule.
# 477                Derive (-C>-P) from ((-P>-C)*(-C>-P)) using the Simplification rule.
# 479                Derive (-C>-P) from ((-P>-C)*(-C>-P)) using the Simplification rule.
# 484                            Derive (P>C) from (-C>-P) using the Contrapositive rule.
# 489                            Derive (P>C) from (-C>-P) using the Contrapositive rule.
# 491                       Derive (--P>C) from (--P>--C) using the Double Negation rule.
# 496                Derive (-C>-P) from ((-P>-C)*(-C>-P)) using the Simplification rule.
# 503                            Derive (P>C) from (-C>-P) using the Contrapositive rule.
# 509                              Derive (-J>-N) from (J+-N) using the Implication rule.
# 511                              Derive (-J>-N) from (J+-N) using the Implication rule.
# 515                                Derive (N>B) from (-N+B) using the Implication rule.
#
#     student_step_new  count_sub next_step_correctness_x  \
# 38                -N          1               Incorrect
# 63               C+D          1                 Correct
# 69                 Y          1              Suboptimal
# 81             --S+Q          0              Suboptimal
# 101               -C          1                 Correct
# 103               -C          1              Suboptimal
# 115               -Y          1                 Correct
# 119               -Y          1              Suboptimal
# 129           S*-Y>Y          0               Incorrect
# 132                S          1                 Correct
# 138                I          1               Incorrect
# 144                S          1               Incorrect
# 152                Y          1               Incorrect
# 156             -S+Y          0              Suboptimal
# 162             -S+Y          1              Suboptimal
# 163                I          1              Suboptimal
# 164                Y          1               Incorrect
# 167               -K          1                 Correct
# 168             -R+P          1                 Correct
# 174               -K          1               Incorrect
# 177             -U+K          1              Suboptimal
# 204              G+D          1               Incorrect
# 207                D          1               Incorrect
# 211                D          1               Incorrect
# 214              D+G          1               Incorrect
# 251                G          1              Suboptimal
# 255              B+F          1               Incorrect
# 260                G          1                 Correct
# 268              B+F          1               Incorrect
# 273              S+X          1              Suboptimal
# 279                S          1               Incorrect
# 299              X+S          1               Incorrect
# 302              X+S          1               Incorrect
# 303              X+T          0              Suboptimal
# 304              X+T          0              Suboptimal
# 311             A+-B          1               Incorrect
# 344            -G>-A          0                 Correct
# 352             -B+D          1               Incorrect
# 356             -B+D          1               Incorrect
# 377             -K*R          0              Suboptimal
# 385               -Z          1               Incorrect
# 391             M*-Z          1               Incorrect
# 392             K*-R          1                 Correct
# 393        -K+Z>-M+R          0                 Correct
# 405            -B>-A          0               Incorrect
# 407            -D>-B          0              Suboptimal
# 408            -D>-A          1               Incorrect
# 410               -D          1               Incorrect
# 411            -B>-A          0              Suboptimal
# 416               -K          1              Suboptimal
# 430            -W>-F          1               Incorrect
# 433           --H*-F          1               Incorrect
# 441          -W>-H+F          1               Incorrect
# 442            -H*-F          1                 Correct
# 444                F          1              Suboptimal
# 449            -W>-F          1               Incorrect
# 454           --H*-F          1               Incorrect
# 463             N>-J          1              Suboptimal
# 473              P>C          1                 Correct
# 474          Y>P*P>C          0              Suboptimal
# 477              P>C          1              Suboptimal
# 479             Y>-P          0              Suboptimal
# 484              Y>P          1                 Correct
# 489             Y>-P          0                 Correct
# 491              Y>C          1              Suboptimal
# 496              Y>P          1              Suboptimal
# 503              Y>P          1              Suboptimal
# 509              B>J          0               Incorrect
# 511             B>-N          1              Suboptimal
# 515             B>-N          1               Incorrect
#
#     next_step_correctness_y next_step_correctness_ours  \
# 38               Suboptimal                 Suboptimal
# 63                Incorrect                  Incorrect
# 69               Suboptimal                  Incorrect
# 81                Incorrect                 Suboptimal
# 101                 Correct                  Incorrect
# 103              Suboptimal                 Suboptimal
# 115               Incorrect                 Suboptimal
# 119              Suboptimal                 Suboptimal
# 129               Incorrect                  Incorrect
# 132              Suboptimal                 Suboptimal
# 138              Suboptimal                 Suboptimal
# 144               Incorrect                  Incorrect
# 152               Incorrect                  Incorrect
# 156              Suboptimal                 Suboptimal
# 162              Suboptimal                 Suboptimal
# 163              Suboptimal                 Suboptimal
# 164              Suboptimal                 Suboptimal
# 167              Suboptimal                  Incorrect
# 168                 Correct                 Suboptimal
# 174              Suboptimal                 Suboptimal
# 177              Suboptimal                 Suboptimal
# 204              Suboptimal                  Incorrect
# 207               Incorrect                  Incorrect
# 211               Incorrect                  Incorrect
# 214               Incorrect                 Suboptimal
# 251              Suboptimal                  Incorrect
# 255               Incorrect                  Incorrect
# 260               Incorrect                  Incorrect
# 268               Incorrect                  Incorrect
# 273               Incorrect                  Incorrect
# 279                 Correct                 Suboptimal
# 299               Incorrect                  Incorrect
# 302              Suboptimal                  Incorrect
# 303              Suboptimal                 Suboptimal
# 304               Incorrect                 Suboptimal
# 311               Incorrect                 Suboptimal
# 344               Incorrect                  Incorrect
# 352               Incorrect                  Incorrect
# 356               Incorrect                  Incorrect
# 377              Suboptimal                 Suboptimal
# 385               Incorrect                  Incorrect
# 391              Suboptimal                  Incorrect
# 392               Incorrect                  Incorrect
# 393              Suboptimal                  Incorrect
# 405              Suboptimal                  Incorrect
# 407               Incorrect                  Incorrect
# 408               Incorrect                  Incorrect
# 410               Incorrect                  Incorrect
# 411              Suboptimal                 Suboptimal
# 416              Suboptimal                 Suboptimal
# 430               Incorrect                  Incorrect
# 433                 Correct                  Incorrect
# 441               Incorrect                  Incorrect
# 442               Incorrect                 Suboptimal
# 444              Suboptimal                 Suboptimal
# 449               Incorrect                  Incorrect
# 454               Incorrect                  Incorrect
# 463              Suboptimal                  Incorrect
# 473               Incorrect                  Incorrect
# 474              Suboptimal                  Incorrect
# 477              Suboptimal                  Incorrect
# 479              Suboptimal                 Suboptimal
# 484              Suboptimal                 Suboptimal
# 489              Suboptimal                 Suboptimal
# 491              Suboptimal                  Incorrect
# 496                 Correct                 Suboptimal
# 503                 Correct                 Suboptimal
# 509               Incorrect                 Suboptimal
# 511               Incorrect                  Incorrect
# 515                 Correct                  Incorrect
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      student_reasoning  \
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         -N is optimal because it can be immediately combined with (K>N) via Modus Tollens to derive -K, which is the conclusion. The other candidates do not directly advance toward the conclusion as efficiently.
# 63                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               (C+D) is optimal because it is the antecedent of ((C+D)>H), and once we have (C+D), we can immediately derive H by Modus Ponens. The other candidates either require (C+D) first or do not directly advance toward H.
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ((Y+S)*(Y+-Q)) is already present in INTERMEDIATE_STEPS, and since both conjuncts contain Y, applying Simp to extract Y directly is optimal. This immediately gives the conclusion without needing to establish -S or Q for disjunctive syllogism.
# 81                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      (-(-S+Q)) is optimal because we already have (-Y>-(-S+Q)) and if we can derive -Y, we can use MP to get -(-S+Q). This directly sets us up to use DN to get (-S+Q), and then MP with ((-S+Q)>Y) to get Y. The other candidates either require an extra step or are less direct.
# 101                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            -C is optimal because we already have -F and (-F>C) in INTERMEDIATE_STEPS, so by Modus Ponens we can directly derive -C. This is a necessary disjunct for the conclusion (-C+-D), and is more direct than trying to conjoin with -D or jump straight to the conclusion.
# 103                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   (-C) is optimal because it is directly a disjunct in the desired conclusion (-C+-D), and is immediately available by simplifying (C*-F). The other candidates either require more steps or introduce elements not yet justified.
# 115                                                                                                                                                                                                                                                                                                                                                                                                                          (-Y) is optimal because we have (--S*-Y) and can simplify it to -Y, which is a direct negation of the conclusion. This sets up a contradiction with S (which we already have), allowing us to derive Y by contradiction in the next step. The other candidates either require Y already or do not directly advance toward the conclusion.
# 119                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        (-Y) is optimal because simplifying (S*-Y) to get -Y directly gives us a negation of the conclusion, which can be used for contradiction or further steps toward Y. The other candidates either do not directly relate to Y or are less immediately useful.
# 129                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        (S*-Y)>Y is optimal because we already have (S*-Y) in INTERMEDIATE_STEPS, and if we derive (S*-Y)>Y, we can immediately use MP to get Y, the CONCLUSION. The other candidates either restate what we already have or skip a necessary step.
# 132                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     S is optimal because --S is already derived, and applying DN gives S directly. With S and (S>Y) (already in INTERMEDIATE_STEPS), we can use MP to get Y, the conclusion. The other candidates either require S first or are the conclusion itself, which we cannot derive yet.
# 138  (S>Y) is optimal because we already have -(S>Y), and (S>Y)+(I*Q) as a given. Using Disjunctive Syllogism on these will allow us to derive (I*Q), which is already in INTERMEDIATE_STEPS, but since the conclusion is Y, and the only way to get Y is from S>Y and S, but we do not have S. The other candidates (I and Q) do not help us get closer to Y. Therefore, the best next step is to try to derive S, but none of the current steps allow that. Thus, the most direct next step is to use Simp on (I*Q) to get I or Q, but since neither leads to Y, the optimal step is to try to use the given (S>Y)+(I*Q) and -(S>Y) to get (I*Q) via DS, but (I*Q) is already in INTERMEDIATE_STEPS. Therefore, the next best step is to use Simp on (I*Q) to get I.
# 144                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Deriving S is optimal because we already have (S>Y) in INTERMEDIATE_STEPS, and if we can get S, we can immediately use MP to derive Y, which is the conclusion. The other candidates are already present or do not directly lead to Y.
# 152                                                                                                                                                                                                                                                                                                                                                                                  Y is optimal because we have (-S+Y) and if we can show -S or S is false, we can get Y by DS. However, since we have (S>Y), and (-S+Y) is equivalent to (S>Y), we can use the tautology that (S>Y) and (-S+Y) together allow us to infer Y by Disjunctive Syllogism if -S is true, or by Modus Ponens if S is true. Since we have both forms, the most direct step is to assert Y.
# 156                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                (-S)+Y is optimal because converting (S>Y) to its disjunctive form allows us to use disjunctive rules (like DS) if -S can be established, or to directly obtain Y if S is false. This is a standard and efficient way to progress toward Y when (S>Y) is available.
# 162                                                                                                                                                                                                                                                                                                                                                                (-S+Y) is optimal because it is the direct implication form of (S>Y) and gives us a disjunction where Y is present, which is a standard step toward isolating Y. The step 'Y' by MP is not valid here since we do not have S as a premise for MP with (S>Y); we only have S as a derived step, but using the implication form is more systematic. (S*Y) does not help directly with the conclusion.
# 163                                                                                                                                                                                                                                                                                                                                                       Simplifying (I*Q) to I or Q is optimal because it gives us atomic components that may be useful for further derivations. However, neither I nor Q directly leads to Y, but having Q or I available could be necessary for further steps. Contraposition on -(S>Y) does not directly yield a useful form for Y. Between I and Q, both are equally useful at this stage, but let's choose I for the next step.
# 164                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Y is optimal because we already have -Y, and by applying DN to -Y, we get --Y, and then by DN again, we get Y, which is the conclusion. This is the most direct route to the conclusion.
# 167                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     (-K) is optimal because we have (K>P) and -P, so by Modus Tollens we can directly derive -K, which is one of the conjuncts needed for the conclusion. The other candidates either repeat an existing step or require -K first.
# 168                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      (-R+P) is optimal because Modus Ponens on '-S' and '(-S*(-R+P))' directly gives us a new disjunction involving R, which is closely tied to the implication (K>R) and may help us derive -K. The other candidates either require more steps or information we do not yet have.
# 174                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                (-K) is optimal because we already have -R from INTERMEDIATE_STEPS, and (K>R) is a given, so Modus Tollens directly gives us -K, which is one of the two literals needed for the conclusion. The other candidates either require -K first or are not derivable yet.
# ...
# 302                                 You’re thinking ahead by targeting the conclusion and considering simplification, which is a good instinct. However, before you can simplify to (X+S), see if you can connect your available implications—are there two statements involving (-X>Y) and (Y>S) that can be combined using a rule to get closer to the conclusion? What happens if you chain these implications together?
# 303                                             Great job recognizing that Addition is a valid rule here! However, think about how you might use both (-Y>X) and (T>S) together to form a conditional that leads more directly to the conclusion. Can you find a rule that combines two conditionals with a disjunction in their antecedents? What would the result look like if you applied that rule to (-Y>X) and (T>S)?
# 304                                                                          Nice use of Addition to combine X and T, and your reasoning about using (T>S) is thoughtful. However, before combining X and T, see if you can use the disjunction (-Y+T) to form a direct implication between Y and T. What rule allows you to turn a disjunction like (-Y+T) into an implication? Try focusing on that transformation first.
# 311                                          You correctly identified that Addition can form the conclusion, but the logical flow in this proof expects you to connect your derived conditionals first. Can you see how the implications involving (-G>A) and (H>-B) might combine to form a new conditional about (A+-B)? What rule could help you merge these implications based on the structure of your previous steps?
# 344                                                                                        You made a thoughtful attempt to connect the statements, but you applied contraposition to a statement that hasn't been derived yet. Instead, consider what you can directly infer from the expressions you already have, especially focusing on how to turn a disjunction into an implication. What rule allows you to do that?
# 352                                                                                                                                            Great job aiming for the conclusion directly! However, DS requires a disjunction and its negation, which you don't have with (-G+D) and (-B+G). Can you look for a way to rewrite one of your current statements as an implication to help bridge the gap to the conclusion?
# 356                                                                                                 You did well to look for a way to reach the conclusion directly, but the rule you chose (CD) doesn't fit the forms of your available statements. Can you identify two implications in your steps that can be linked together using a rule that chains implications? What happens if you try to connect (B>G) and (G>D)?
# 377                                        Great job applying De Morgan's Law and thinking about how to connect statements! While forming the conjunction is valid, consider how combining the implications you have might help you create a statement that links more directly to the conclusion. What happens if you use both (-M>-K) and (Z>R) together—can you form a new implication that brings you closer to (M*-Z)?
# 385                                              You correctly identified that obtaining -Z would help, but the rule you applied doesn't fit the statements you chose. Think about which conditional in your intermediate steps has (K>R) as its consequent, and consider how you might use its negation with Modus Tollens. Which statement could you apply MT to in order to get a negation that brings you closer to -Z?
# 391                                                                                                             You correctly noticed that M and -Z are available, but there's an important intermediate step involving --K that should be addressed before forming the final conjunction. Can you identify how --K is derived from your current statements, and why this step might be necessary before concluding (M*-Z)?
# 392                                                                                                                           You made a good attempt at using contraposition, but notice that the step should be applied to (K>M) rather than to the negated implication. Can you try applying the contrapositive rule to (K>M) and see what new statement you get? How might that help you move closer to the conclusion?
# 393                                                                                                                                                  You correctly identified the usefulness of contraposition, but it should be applied to (K>M) rather than to ((K+Z)>(M+R)). Can you try applying contraposition to one of your original givens and see how that might help connect to the negated conditional you have?
# 405                                                                                                                                  You recognized the importance of (-B>-A), but applying DN here is not justified. Instead, think about how you can use (D+B) to introduce a conditional involving -D, which will help you get closer to the conclusion. What rule allows you to rewrite a disjunction as a conditional?
# 407                                                                           You’re thinking ahead about chaining implications, which is great! However, the step you chose doesn’t follow from the rules available for your current statements. Is there a way to transform (A>-B) so that its form matches what you need for hypothetical syllogism? Think about how you might rewrite implications to connect -D to -A.
# 408                                                                       Great job recognizing which expressions are close to the conclusion! However, before you can reach (-D>-A), think about how you can simplify (--B>-A) using a basic rule about double negation. What happens if you remove the double negation from --B? Which rule allows you to do that, and how does it help you get closer to the conclusion?
# 410                                                           You correctly noticed that -D is important for the conclusion, but you tried to use DS with -B before actually deriving -B. Instead, consider what you can directly derive from (D+B) using the rules you know—can you rewrite it in a form that might help you get closer to the conclusion? What rule allows you to turn a disjunction into an implication?
# 411                                                                                                     Nice work identifying the contrapositive, which is a valid move, but consider if combining your current implications could get you closer to the conclusion more directly. Which two implications do you have now that could be linked using a standard inference rule to form a new implication involving A and D?
# 416                                                        You’ve made a strong observation about the importance of -K, but notice that the next step in the standard solution is to transform the conditional statement first. What rule could you use to rewrite the conditional so that it’s easier to work with the antecedent? Try focusing on the structure of the conditional before deriving individual components.
# 430                                  You made a good attempt to connect the statements, but simplifying the consequent of an implication like this isn't a valid logical move. Instead, think about how you might re-express the entire implication to relate (H+F) directly to W—what rule allows you to switch the antecedent and consequent with their negations? Try to identify that transformation before proceeding.
# 433                                                                 You made a good observation about needing to connect --(H+F) to the implication's consequent, but applying double negation here skips an important step. Can you think of a rule that allows you to rewrite the negation of a disjunction so it matches the form of the implication's consequent? What happens if you apply De Morgan's Law to --(H+F)?
# 441                                                    Great job connecting the givens and your derived steps! However, the transformation you suggested isn't justified by the rules at this point. Instead, think about how you can use the implication and the negation you've already derived together—what rule allows you to infer something about W from these? What would happen if you applied Modus Tollens here?
# 442                                                                                                                                                   Nice use of double negation! However, think about how you can use the statements you have, especially -(-H*-F) and the conditional (-W>(-H*-F)), to get closer to W. Is there a rule that lets you connect these two directly to make progress toward the conclusion?
# 444                                               Great job recognizing the importance of (H+F) and considering how to use it! While simplifying to F is a valid move, think about how you might re-express (H+F) to better connect with the implications involving negations in your givens. Is there a way to introduce or manipulate negations here that could help you use the conditional statements more effectively?
# 449                                                               Great job exploring different ways to manipulate the statements! However, before introducing new implications, try focusing on simplifying what you already have. For example, is there a way to restate (H+F) using a basic logical rule that might make it easier to connect with other statements? What happens if you apply double negation to (H+F)?
# 454                                                                            Great job recognizing the importance of (W+(-H*-F))! However, applying MT here isn't justified by the statements you have. Instead, think about how you might break down or restructure (W+(-H*-F)) using a rule that lets you distribute or separate the components. What happens if you try to expand this disjunction using distribution?
# 463                                                                                       You're on the right track by aiming for the conclusion and recognizing the use of HS. However, before you can apply HS, make sure the statements you need are explicitly available and properly arranged. Can you think of a way to reorganize your existing conjunction so that both implications are clearly accessible for HS?
# 473                                                                                                                         Great job recognizing that (P>C) is a key step toward the conclusion! However, check the rule you used—can you recall which rule allows you to switch the order and negate both terms in a conditional? Try to identify the correct rule for deriving (P>C) from (-C>-P) before moving forward.
# 474                                                            You’ve correctly identified (Y>P) as a key implication, but the next step should be to isolate it from the biconditional using the appropriate rule. Why might it be helpful to focus on extracting just (Y>P) before combining it with other statements? Try to think about which single implication you can directly obtain from your current expressions.
# 477                                                           You’re on the right track by thinking about how to connect (P>C) to your goal, but before applying contraposition, try to focus on extracting all relevant conditionals from your biconditional statement using basic rules. Which rule allows you to separate the two parts of a conjunction or biconditional? What can you do with ((-P>-C)*(-C>-P)) first?
# 479                                                                                                                 Nice work recognizing the potential of contraposition! Before applying that, see if you can extract a statement directly from your existing conjunctions using a basic rule. Which part of your givens can be isolated with a single step to help you connect to the other statements more efficiently?
# 484                                                                                                                                                     Nice work extracting (Y>P); that's a valid move. However, consider if there's a way to directly relate P to C using the implications you have—can you transform any of your current statements to get an implication from P to C? What rule might help you do that?
# 489                                   Nice work extracting (Y>-P) from the biconditional! While this is a valid move, consider if there are other statements you can transform to get an implication that connects more directly to C. For example, is there a way to rewrite any of your current implications so that C appears as a consequent? What happens if you apply contraposition to one of your given statements?
# 491                                                                                                     You're on the right track with using Hypothetical Syllogism, but before you can chain (Y>P) and (P>C), make sure you have all the necessary implications in the correct form. Is there a way to rewrite (--P>--C) so it can help you derive (P>C)? What rule allows you to remove double negations in implications?
# 496                                       Nice work identifying the importance of extracting implications from biconditionals! While (Y>P) is a valid step, think about which available implications connect more directly to C, since your goal is (Y>C). Can you spot a statement that, if simplified, would immediately give you an implication involving C? Try focusing on the biconditional that already contains -C.
# 503                                                      Great job recognizing the value of implication forms and thinking about chaining! However, since (Y>P) is already available, let's focus on creating a new implication that connects P to C. Can you use any of the existing statements to derive an implication from P to C? What rule might help you transform (-C>-P) into a more useful form for this purpose?
# 509                                                               Nice work recognizing the need to connect B and J, and your reasoning about using a conditional is solid. However, consider whether focusing on the relationship between J and -N might get you closer to the conclusion more directly. What happens if you try to express (J+-N) as a conditional? How could that help you link to the other statements?
# 511  You correctly identified the conclusion and the relevance of implication, but the direct application of Impl to (B+-N) skips a necessary intermediate step. Can you look at your available statements and see if applying implication to a different disjunction might help you build a bridge toward the conclusion? Which disjunction could you use to form a new conditional that could be useful in the next step?
# 515                                                   You made a good attempt to connect (B) and (-N), but remember that (B+-N) is not equivalent to (B>-N) by implication equivalence. Instead, look at your derived or given disjunctions—can you apply implication equivalence to one of them to get a conditional statement that helps you move toward the conclusion? Which candidate in your list fits this approach?

# %% [markdown]
# # Regression preprocessing

# %%
# student_df
df_student = df[['id','KG_step_new' ,'KG_rule', 'KG_complexity', 'KG_distance', 'student_step_new', 'student_rule']].copy()
df_student['correct'] = df_student.apply(lambda row: 1 if (row['student_rule'] == row['KG_rule']) and (row['student_step_new'] == row['KG_step_new']) else 0, axis=1)
# add a column to df_student called 'model' which contains the "GPT-4.1"
df_student['model'] = "GPT-4.1"
# add a column to df_student called 'pipeline' which contains the "student only"
df_student['pipeline'] = "student only"
df_student.head()
# drop the KG_step, KG_rule, student_step, student_rule columns
df_student = df_student.drop(columns=['KG_step_new', 'KG_rule', 'student_step_new', 'student_rule'])

# pipeline 2 student-teacher
df_teacher = df[['id','KG_step' ,'KG_rule', 'KG_complexity', 'KG_distance', 'student_update_step', 'student_update_rule']].copy()
df_teacher['correct'] = df_teacher.apply(lambda row: 1 if (row['student_update_rule'] == row['KG_rule']) and (row['student_update_step'] == row['KG_step']) else 0, axis=1)
# add a column to df_student called 'model' which contains the "GPT-4.1"
df_teacher['model'] = "GPT-4.1"
# add a column to df_student called 'pipeline' which contains the "student only"
df_teacher['pipeline'] = "student-teacher"
df_teacher.head()
# drop the KG_step, KG_rule, student_step, student_rule columns
df_teacher = df_teacher.drop(columns=['KG_step', 'KG_rule', 'student_update_step', 'student_update_rule'])
df_teacher.head()


# pipeline 3 student-judge
df_judge = df[['id','KG_step' ,'KG_rule', 'KG_complexity', 'KG_distance', 'judge_student_update_step', 'judge_student_update_rule']].copy()
df_judge['correct'] = df_judge.apply(lambda row: 1 if (row['judge_student_update_rule'] == row['KG_rule']) and (row['judge_student_update_step'] == row['KG_step']) else 0, axis=1)
# add a column to df_student called 'model' which contains the "GPT-4.1"
df_judge['model'] = "GPT-4.1"
# add a column to df_student called 'pipeline' which contains the "student only"
df_judge['pipeline'] = "student-judge"
df_judge.head()
# drop the KG_step, KG_rule, student_step, student_rule columns
df_judge = df_judge.drop(columns=['KG_step', 'KG_rule', 'judge_student_update_step', 'judge_student_update_rule'])
df_judge.head()


# pipeline 4 student-teacher-judge
df_teacher_judge = df[['id','KG_step' ,'KG_rule', 'KG_complexity', 'KG_distance', 'ours_student_update_step', 'ours_student_update_rule']].copy()
df_teacher_judge['correct'] = df_teacher_judge.apply(lambda row: 1 if (row['ours_student_update_rule'] == row['KG_rule']) and (row['ours_student_update_step'] == row['KG_step']) else 0, axis=1)
# add a column to df_student called 'model' which contains the "GPT-4.1"
df_teacher_judge['model'] = "GPT-4.1"
# add a column to df_student called 'pipeline' which contains the "student only"
df_teacher_judge['pipeline'] = "student-teacher-judge"
df_teacher_judge.head()
# drop the KG_step, KG_rule, student_step, student_rule columns
df_teacher_judge = df_teacher_judge.drop(columns=['KG_step', 'KG_rule', 'ours_student_update_step', 'ours_student_update_rule'])
df_teacher_judge.head()


#vertical concat all dataframes
df_all = pd.concat([df_student, df_teacher, df_judge, df_teacher_judge])
print(df_all.shape)
df_all.head()
# Out:
# (2064, 6)
#    id  KG_complexity  KG_distance  correct    model      pipeline
# 0   1              2            1        1  GPT-4.1  student only
# 1   2              1            3        0  GPT-4.1  student only
# 2   3              0            0        1  GPT-4.1  student only
# 3   4              3            2        1  GPT-4.1  student only
# 4   5              3            2        0  GPT-4.1  student only

# %%
df_all['pipeline'].unique()
# Out:
# array(['student only', 'student-teacher', 'student-judge',
#        'student-teacher-judge'], dtype=object)

# %%
import statsmodels.formula.api as smf

# Ensure categorical variables are treated properly
df_all['pipeline'] = df_all['pipeline'].astype('category')
df_all['model'] = df_all['model'].astype('category')

# Logistic regression
model = smf.logit(
    formula="""
        correct ~ pipeline 
        + KG_complexity 
        + KG_distance
        + pipeline * KG_complexity
        + pipeline * KG_distance

    """,
    data=df_all
).fit()

print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.553618
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                correct   No. Observations:                 2064
# Model:                          Logit   Df Residuals:                     2052
# Method:                           MLE   Df Model:                           11
# Date:                Mon, 12 Jan 2026   Pseudo R-squ.:                  0.1124
# Time:                        15:44:37   Log-Likelihood:                -1142.7
# converged:                       True   LL-Null:                       -1287.4
# Covariance Type:            nonrobust   LLR p-value:                 1.469e-55
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.9965      0.270      3.689      0.000       0.467       1.526
# pipeline[T.student-judge]                          -1.4922      0.353     -4.228      0.000      -2.184      -0.800
# pipeline[T.student-teacher]                        -2.4371      0.387     -6.292      0.000      -3.196      -1.678
# pipeline[T.student-teacher-judge]                  -0.9005      0.342     -2.630      0.009      -1.572      -0.229
# KG_complexity                                      -0.4188      0.070     -5.997      0.000      -0.556      -0.282
# pipeline[T.student-judge]:KG_complexity             0.1836      0.084      2.194      0.028       0.020       0.348
# pipeline[T.student-teacher]:KG_complexity           0.1267      0.093      1.370      0.171      -0.055       0.308
# pipeline[T.student-teacher-judge]:KG_complexity     0.2442      0.080      3.065      0.002       0.088       0.400
# KG_distance                                        -0.4368      0.079     -5.516      0.000      -0.592      -0.282
# pipeline[T.student-judge]:KG_distance               0.6174      0.101      6.102      0.000       0.419       0.816
# pipeline[T.student-teacher]:KG_distance             0.7508      0.108      6.954      0.000       0.539       0.962
# pipeline[T.student-teacher-judge]:KG_distance       0.5420      0.099      5.475      0.000       0.348       0.736
# ===================================================================================================================

# %%
import numpy as np

# Add OR column
results_df = pd.DataFrame({
    'Predictor': model.params.index,
    'β': model.params.values,
    'SE': model.bse.values,
    'OR': np.exp(model.params.values),
    'CI_lower': np.exp(model.conf_int()[0]),
    'CI_upper': np.exp(model.conf_int()[1]),
    'p': model.pvalues.values
})

print(results_df.round(3))
# Out:
#                                                                                        Predictor  \
# Intercept                                                                              Intercept
# pipeline[T.student-judge]                                              pipeline[T.student-judge]
# pipeline[T.student-teacher]                                          pipeline[T.student-teacher]
# pipeline[T.student-teacher-judge]                              pipeline[T.student-teacher-judge]
# KG_complexity                                                                      KG_complexity
# pipeline[T.student-judge]:KG_complexity                  pipeline[T.student-judge]:KG_complexity
# pipeline[T.student-teacher]:KG_complexity              pipeline[T.student-teacher]:KG_complexity
# pipeline[T.student-teacher-judge]:KG_complexity  pipeline[T.student-teacher-judge]:KG_complexity
# KG_distance                                                                          KG_distance
# pipeline[T.student-judge]:KG_distance                      pipeline[T.student-judge]:KG_distance
# pipeline[T.student-teacher]:KG_distance                  pipeline[T.student-teacher]:KG_distance
# pipeline[T.student-teacher-judge]:KG_distance      pipeline[T.student-teacher-judge]:KG_distance
#
#                                                      β     SE     OR  \
# Intercept                                        0.996  0.270  2.709
# pipeline[T.student-judge]                       -1.492  0.353  0.225
# pipeline[T.student-teacher]                     -2.437  0.387  0.087
# pipeline[T.student-teacher-judge]               -0.900  0.342  0.406
# KG_complexity                                   -0.419  0.070  0.658
# pipeline[T.student-judge]:KG_complexity          0.184  0.084  1.201
# pipeline[T.student-teacher]:KG_complexity        0.127  0.093  1.135
# pipeline[T.student-teacher-judge]:KG_complexity  0.244  0.080  1.277
# KG_distance                                     -0.437  0.079  0.646
# pipeline[T.student-judge]:KG_distance            0.617  0.101  1.854
# pipeline[T.student-teacher]:KG_distance          0.751  0.108  2.119
# pipeline[T.student-teacher-judge]:KG_distance    0.542  0.099  1.719
#
#                                                  CI_lower  CI_upper      p
# Intercept                                           1.595     4.600  0.000
# pipeline[T.student-judge]                           0.113     0.449  0.000
# pipeline[T.student-teacher]                         0.041     0.187  0.000
# pipeline[T.student-teacher-judge]                   0.208     0.795  0.009
# KG_complexity                                       0.574     0.754  0.000
# pipeline[T.student-judge]:KG_complexity             1.020     1.416  0.028
# pipeline[T.student-teacher]:KG_complexity           0.947     1.361  0.171
# pipeline[T.student-teacher-judge]:KG_complexity     1.092     1.492  0.002
# KG_distance                                         0.553     0.755  0.000
# pipeline[T.student-judge]:KG_distance               1.521     2.261  0.000
# pipeline[T.student-teacher]:KG_distance             1.715     2.618  0.000
# pipeline[T.student-teacher-judge]:KG_distance       1.416     2.088  0.000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pipelines = df_all['pipeline'].unique()

distance_range = np.linspace(
    df_all['KG_distance'].min(),
    df_all['KG_distance'].max(),
    50
)

mean_complexity = df_all['KG_complexity'].mean()

plot_rows = []
for p in pipelines:
    for d in distance_range:
        plot_rows.append({
            'pipeline': p,
            'KG_distance': d,
            'KG_complexity': mean_complexity
        })

plot_df = pd.DataFrame(plot_rows)

# Predict probabilities from fitted model
plot_df['pred_prob'] = model.predict(plot_df)

plt.figure(figsize=(8, 5))
for p in pipelines:
    subset = plot_df[plot_df['pipeline'] == p]
    plt.plot(
        subset['KG_distance'],
        subset['pred_prob'],
        label=p,
        linewidth=2
    )

plt.xlabel("Gold Derivational Distance")
plt.ylabel("Predicted Probability of Correct Step")
plt.title("Regression Effect of Distance by Pipeline")
plt.legend(title="Pipeline")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
complexity_range = np.linspace(
    df_all['KG_complexity'].min(),
    df_all['KG_complexity'].max(),
    50
)

mean_distance = df_all['KG_distance'].mean()

plot_rows = []
for p in pipelines:
    for c in complexity_range:
        plot_rows.append({
            'pipeline': p,
            'KG_complexity': c,
            'KG_distance': mean_distance
        })

plot_df = pd.DataFrame(plot_rows)
plot_df['pred_prob'] = model.predict(plot_df)

plt.figure(figsize=(8, 5))
for p in pipelines:
    subset = plot_df[plot_df['pipeline'] == p]
    plt.plot(
        subset['KG_complexity'],
        subset['pred_prob'],
        label=p,
        linewidth=2
    )

plt.xlabel("Gold Step Complexity")
plt.ylabel("Predicted Probability of Correct Step")
plt.title("Regression Effect of Complexity by Pipeline")
plt.legend(title="Pipeline")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

sns.lmplot(
    data=df_all,
    x="KG_complexity",
    y="correct",
    col="pipeline",
    logistic=True,
    ci=95,
    height=4,
    aspect=1
)

# %%
import seaborn as sns

sns.lmplot(
    data=df_all,
    x="KG_distance",
    y="correct",
    col="pipeline",
    logistic=True,
    ci=95,
    height=4,
    aspect=1
)

# %% [markdown]
# # Regression for student details

# %%
# add student_complexity, student_depth, student_distance from df to df_student, df_teacher, df_judge, df_teacher_judge
df_student_1= pd.concat([df_student, df[['student_complexity', 'student_depth', 'student_distance']]], axis=1)
df_teacher_1 = pd.concat([df_teacher, df[['student_complexity', 'student_depth', 'student_distance']]], axis=1)
df_judge_1 = pd.concat([df_judge, df[['student_complexity', 'student_depth', 'student_distance']]], axis=1)
df_teacher_judge_1 = pd.concat([df_teacher_judge, df[['student_complexity', 'student_depth', 'student_distance']]], axis=1)

# Safe function to evaluate literal expressions - handles both strings and already-parsed lists
def safe_literal_eval(x):
    if isinstance(x, str):
        return ast.literal_eval(x)
    elif isinstance(x, (list, tuple)):
        return x
    else:
        return x

df['known_expressions'] = df['known_expressions'].apply(safe_literal_eval)
df['known_expressions_length'] = df['known_expressions'].apply(len)
df['student_parent_statements'] = df['student_parent_statements'].apply(safe_literal_eval)
df['parents_length'] = df['student_parent_statements'].apply(len)
df['student_parent_complexity'] = df['student_parent_complexities'].apply(lambda x: sum(ast.literal_eval(x) if isinstance(x, str) else x))
df['student_parent_complexity'] = df['student_parent_complexities'].apply(sum)


# Now add this to all dataframes
df_student_1['known_expressions'] = df['known_expressions_length']
df_teacher_1['known_expressions'] = df['known_expressions_length']
df_judge_1['known_expressions'] = df['known_expressions_length']
df_teacher_judge_1['known_expressions'] = df['known_expressions_length']

df_student_1['parents_length'] = df['parents_length']
df_teacher_1['parents_length'] = df['parents_length']
df_judge_1['parents_length'] = df['parents_length']
df_teacher_judge_1['parents_length'] = df['parents_length']

df_student_1['parent_complexity'] = df['student_parent_complexity']
df_teacher_1['parent_complexity'] = df['student_parent_complexity']
df_judge_1['parent_complexity'] = df['student_parent_complexity']
df_teacher_judge_1['parent_complexity'] = df['student_parent_complexity']


df_student.head()
df_all_1 = pd.concat([df_student_1, df_teacher_1, df_judge_1, df_teacher_judge_1])
print(df_all_1.shape)
df_all_1.head()

# Regression for student details 
# add student_complexity, student_depth, student_distance from to df_student
# Out:
# (2064, 12)
#    id  KG_complexity  KG_distance  correct    model      pipeline  \
# 0   1              2            1        1  GPT-4.1  student only
# 1   2              1            3        0  GPT-4.1  student only
# 2   3              0            0        1  GPT-4.1  student only
# 3   4              3            2        1  GPT-4.1  student only
# 4   5              3            2        0  GPT-4.1  student only
#
#    student_complexity  student_depth  student_distance  known_expressions  \
# 0                   2            1.0                 1                  5
# 1                   0            2.0                 2                  3
# 2                   0            1.0                 3                  6
# 3                   3            1.0                 2                  4
# 4                   2            2.0                 1                  7
#
#    parents_length  parent_complexity
# 0               1                  0
# 1               1                  2
# 2               1                  2
# 3               1                  1
# 4               2                  8

# %%
df_all_1['pipeline'].unique()
# Out:
# array(['student only', 'student-teacher', 'student-judge',
#        'student-teacher-judge'], dtype=object)

# %%
formula_interaction = """
correct ~ pipeline + KG_complexity + KG_distance + 
          pipeline:KG_complexity + pipeline:KG_distance

"""
result = smf.logit(
    formula=formula_interaction,
    data=df_all_1
).fit()

print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.553618
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                correct   No. Observations:                 2064
# Model:                          Logit   Df Residuals:                     2052
# Method:                           MLE   Df Model:                           11
# Date:                Mon, 12 Jan 2026   Pseudo R-squ.:                  0.1124
# Time:                        15:44:44   Log-Likelihood:                -1142.7
# converged:                       True   LL-Null:                       -1287.4
# Covariance Type:            nonrobust   LLR p-value:                 1.469e-55
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.9965      0.270      3.689      0.000       0.467       1.526
# pipeline[T.student-judge]                          -1.4922      0.353     -4.228      0.000      -2.184      -0.800
# pipeline[T.student-teacher]                        -2.4371      0.387     -6.292      0.000      -3.196      -1.678
# pipeline[T.student-teacher-judge]                  -0.9005      0.342     -2.630      0.009      -1.572      -0.229
# KG_complexity                                      -0.4188      0.070     -5.997      0.000      -0.556      -0.282
# pipeline[T.student-judge]:KG_complexity             0.1836      0.084      2.194      0.028       0.020       0.348
# pipeline[T.student-teacher]:KG_complexity           0.1267      0.093      1.370      0.171      -0.055       0.308
# pipeline[T.student-teacher-judge]:KG_complexity     0.2442      0.080      3.065      0.002       0.088       0.400
# KG_distance                                        -0.4368      0.079     -5.516      0.000      -0.592      -0.282
# pipeline[T.student-judge]:KG_distance               0.6174      0.101      6.102      0.000       0.419       0.816
# pipeline[T.student-teacher]:KG_distance             0.7508      0.108      6.954      0.000       0.539       0.962
# pipeline[T.student-teacher-judge]:KG_distance       0.5420      0.099      5.475      0.000       0.348       0.736
# ===================================================================================================================

# %%
# Extract coefficients from statsmodels
import pandas as pd
import numpy as np

# Extract coefficients
coef_df = pd.DataFrame({
    "term": result.params.index,
    "coef": result.params.values,
    "ci_low": result.conf_int()[0].values,
    "ci_high": result.conf_int()[1].values,
    "p_value": result.pvalues.values
})

# Remove intercept (usually not informative in forest plots)
coef_df = coef_df[coef_df["term"] != "Intercept"]

# Optional: sort for nicer plotting
coef_df = coef_df.sort_values("coef")

# Clean up term names (important for paper quality)
def pretty_term(term):
    term = term.replace("pipeline[T.", "")
    term = term.replace("]", "")
    term = term.replace(":", " × ")
    term = term.replace("_", " ")
    return term.title()

coef_df["term_pretty"] = coef_df["term"].apply(pretty_term)

# Draw the coefficient forest plot
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

# Plot confidence intervals
plt.hlines(
    y=coef_df["term_pretty"],
    xmin=coef_df["ci_low"],
    xmax=coef_df["ci_high"],
    color="gray",
    alpha=0.8
)

# Plot point estimates
plt.scatter(
    coef_df["coef"],
    coef_df["term_pretty"],
    color="black",
    zorder=3
)

# Vertical zero line
plt.axvline(0, color="red", linestyle="--", linewidth=1)

plt.xlabel("Log-Odds Coefficient (β)")
plt.ylabel("")
plt.title("Logistic Regression Coefficient Forest Plot")

plt.tight_layout()
plt.show()


# Highlight statistically significant effects (optional but recommended)
sig = coef_df["p_value"] < 0.05

plt.figure(figsize=(8, 6))

plt.hlines(
    coef_df["term_pretty"],
    coef_df["ci_low"],
    coef_df["ci_high"],
    color=["black" if s else "lightgray" for s in sig]
)

plt.scatter(
    coef_df["coef"],
    coef_df["term_pretty"],
    c=["black" if s else "lightgray" for s in sig],
    zorder=3
)

plt.axvline(0, color="red", linestyle="--")
plt.xlabel("Log-Odds Coefficient (β)")
plt.title("Significant Effects Highlighted")
plt.tight_layout()
plt.show()

# %%
model_clustered = smf.logit(
    formula=formula_interaction,
    data=df_all_1
).fit(
    cov_type="cluster",
    cov_kwds={"groups": df_all_1["id"]}
)

print(model_clustered.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.553618
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                correct   No. Observations:                 2064
# Model:                          Logit   Df Residuals:                     2052
# Method:                           MLE   Df Model:                           11
# Date:                Mon, 12 Jan 2026   Pseudo R-squ.:                  0.1124
# Time:                        15:44:44   Log-Likelihood:                -1142.7
# converged:                       True   LL-Null:                       -1287.4
# Covariance Type:              cluster   LLR p-value:                 1.469e-55
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.9965      0.259      3.852      0.000       0.489       1.504
# pipeline[T.student-judge]                          -1.4922      0.407     -3.666      0.000      -2.290      -0.694
# pipeline[T.student-teacher]                        -2.4371      0.419     -5.822      0.000      -3.258      -1.617
# pipeline[T.student-teacher-judge]                  -0.9005      0.417     -2.158      0.031      -1.718      -0.083
# KG_complexity                                      -0.4188      0.056     -7.501      0.000      -0.528      -0.309
# pipeline[T.student-judge]:KG_complexity             0.1836      0.083      2.200      0.028       0.020       0.347
# pipeline[T.student-teacher]:KG_complexity           0.1267      0.093      1.357      0.175      -0.056       0.310
# pipeline[T.student-teacher-judge]:KG_complexity     0.2442      0.078      3.135      0.002       0.092       0.397
# KG_distance                                        -0.4368      0.089     -4.924      0.000      -0.611      -0.263
# pipeline[T.student-judge]:KG_distance               0.6174      0.132      4.661      0.000       0.358       0.877
# pipeline[T.student-teacher]:KG_distance             0.7508      0.135      5.548      0.000       0.486       1.016
# pipeline[T.student-teacher-judge]:KG_distance       0.5420      0.135      4.027      0.000       0.278       0.806
# ===================================================================================================================
